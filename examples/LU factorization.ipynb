# %%
using UnumX

# %%
X = map(Ubound34, randn(5,5))
# Out:
# 5x5 Array{UnumX.Interval{UnumX.Unum{3,4,UInt64}},2}:
#  (-1.2035675048828125,-1.20355224609375)       …  (-0.6976852416992188,-0.6976776123046875)
#  (-0.16884231567382812,-0.1688404083251953)       (-0.5886917114257812,-0.58868408203125)
#  (-0.5665206909179688,-0.5665130615234375)         (1.717437744140625,1.7174530029296875)
#   (0.5644683837890625,0.5644760131835938)          (1.66143798828125,1.6614532470703125)
#   (0.029825687408447266,0.029825925827026367)     (-0.4367027282714844,-0.43669891357421875)

# %%
L,U,p = lu(X,Val{false}) # disable pivoting
# Out:
# (
# 5x5 Array{UnumX.Interval{UnumX.Unum{3,4,UInt64}},2}:
#    1.0                                         …  0.0
#   (0.14028167724609375,0.140289306640625)         0.0
#   (0.4706878662109375,0.47071075439453125)        0.0
#  (-0.4690132141113281,-0.4689903259277344)        0.0
#  (-0.02478194236755371,-0.024780750274658203)     1.0,
#
# 5x5 Array{UnumX.Interval{UnumX.Unum{3,4,UInt64}},2}:
#  (-1.2035675048828125,-1.20355224609375)  …  (-0.6976852416992188,-0.6976776123046875)
#    0.0                                       (-0.49082183837890625,-0.4908027648925781)
#    0.0                                        (2.29534912109375,2.29547119140625)
#    0.0                                       (28.4765625,28.494140625)
#    0.0                                        (2.9521484375,3.01611328125)             ,
#
# [1,2,3,4,5])

# %%
L*U
# Out:
# 5x5 Array{UnumX.Interval{UnumX.Unum{3,4,UInt64}},2}:
#  (-1.2035675048828125,-1.20355224609375)      …  (-0.6976852416992188,-0.6976776123046875)
#  (-0.16884803771972656,-0.16883468627929688)     (-0.5887069702148438,-0.5886688232421875)
#  (-0.5665359497070312,-0.5664901733398438)        (1.71734619140625,1.7175445556640625)
#   (0.564453125,0.5644912719726562)                (1.64404296875,1.678955078125)
#   (0.02982473373413086,0.029826879501342773)     (-0.500732421875,-0.372802734375)

# %%
L*U - X
# Out:
# 5x5 Array{UnumX.Interval{UnumX.Unum{3,4,UInt64}},2}:
#  (-1.52587890625e-5,1.52587890625e-5)            …  (-7.62939453125e-6,7.62939453125e-6)
#  (-7.62939453125e-6,7.62939453125e-6)               (-2.288818359375e-5,2.288818359375e-5)
#  (-2.288818359375e-5,3.0517578125e-5)               (-0.0001068115234375,0.0001068115234375)
#  (-2.288818359375e-5,2.288818359375e-5)             (-0.0174102783203125,0.01751708984375)
#  (-1.1920928955078125e-6,1.1920928955078125e-6)     (-0.06403350830078125,0.06389999389648438)

# %%
Lp,Up,p = lu(X) # with pivoting
# Out:
# (
# 5x5 Array{UnumX.Interval{UnumX.Unum{3,4,UInt64}},2}:
#    1.0                                         …  0.0
#   (0.14028167724609375,0.140289306640625)         0.0
#  (-0.4690132141113281,-0.4689903259277344)        0.0
#   (0.4706878662109375,0.47071075439453125)        0.0
#  (-0.02478194236755371,-0.024780750274658203)     1.0,
#
# 5x5 Array{UnumX.Interval{UnumX.Unum{3,4,UInt64}},2}:
#  (-1.2035675048828125,-1.20355224609375)  …  (-0.6976852416992188,-0.6976776123046875)
#    0.0                                       (-0.49082183837890625,-0.4908027648925781)
#    0.0                                        (1.43304443359375,1.4331207275390625)
#    0.0                                        (2.416900634765625,2.4171142578125)
#    0.0                                        (2.983612060546875,2.98504638671875)     ,
#
# [1,2,4,3,5])

# %%
Lp*Up - X[p,:]
# Out:
# 5x5 Array{UnumX.Interval{UnumX.Unum{3,4,UInt64}},2}:
#  (-1.52587890625e-5,1.52587890625e-5)            …  (-7.62939453125e-6,7.62939453125e-6)
#  (-7.62939453125e-6,7.62939453125e-6)               (-2.288818359375e-5,2.288818359375e-5)
#  (-2.288818359375e-5,2.288818359375e-5)             (-6.103515625e-5,7.62939453125e-5)
#  (-2.288818359375e-5,3.0517578125e-5)               (-0.0001983642578125,0.00018310546875)
#  (-1.1920928955078125e-6,1.1920928955078125e-6)     (-0.00144195556640625,0.001430511474609375)
